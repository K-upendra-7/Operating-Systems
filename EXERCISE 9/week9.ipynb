# %%
import random
import matplotlib.pyplot as plt


# -------- GRAPH FUNCTION --------
def plot_graph(order, title):
    plt.figure(figsize=(12, 6))   # 2:1 ratio

    y = [i/2 for i in range(len(order))]   # scaled Y-axis
    plt.plot(order, y, marker='o')
    plt.gca().invert_yaxis()

    plt.xlabel("Cylinder Number")
    plt.ylabel("Step Number")
    plt.title(title)

    plt.show()


# -------- C-SCAN (Jump INCLUDED) --------
def cscan(queue, head, start, end, direction):

    left = sorted([x for x in queue if x < head])
    right = sorted([x for x in queue if x >= head])

    order = [head]

    if direction == "right":
        order += right
        order.append(end)
        order.append(start)
        order += left

    else:  # left
        order += left[::-1]
        order.append(start)
        order.append(end)
        order += right[::-1]

    # INCLUDE jump → no skipping
    total = 0
    for i in range(len(order)-1):
        total += abs(order[i+1] - order[i])

    print("\nC-SCAN ")
    print("Service Order:", order)
    print("Total Head Movement:", total)

    plot_graph(order, "C-SCAN Disk Scheduling")


# -------- LOOK --------
def look(queue, head, direction):

    left = sorted([x for x in queue if x < head])
    right = sorted([x for x in queue if x >= head])

    order = [head]

    if direction == "right":
        order += right
        order += left[::-1]

    else:
        order += left[::-1]
        order += right

    total = 0
    for i in range(len(order)-1):
        total += abs(order[i+1] - order[i])

    print("\nLOOK")
    print("Service Order:", order)
    print("Total Head Movement:", total)

    plot_graph(order, "LOOK Disk Scheduling")


# -------- C-LOOK (Jump INCLUDED) --------
def clook(queue, head, direction):

    left = sorted([x for x in queue if x < head])
    right = sorted([x for x in queue if x >= head])

    order = [head]

    if direction == "right":
        order += right
        order += left   # circular jump happens here

    else:
        order += left[::-1]
        order += right[::-1]  # circular jump happens here

    # INCLUDE jump
    total = 0
    for i in range(len(order)-1):
        total += abs(order[i+1] - order[i])

    print("\nC-LOOK")
    print("Service Order:", order)
    print("Total Head Movement:", total)

    plot_graph(order, "C-LOOK Disk Scheduling")


# -------- MAIN --------
start = int(input("Enter start cylinder: "))
end = int(input("Enter end cylinder: "))
qsize = int(input("Enter queue size: "))

queue = [random.randint(start, end) for _ in range(qsize)]
head = random.randint(start, end)

print("\nQueue:", queue)
print("Head:", head)

print("\n----- MENU -----")
print("1. C-SCAN")
print("2. LOOK")
print("3. C-LOOK")

choice = int(input("Enter choice: "))

print("\nDirection:")
print("1. Left")
print("2. Right")

d = int(input("Enter direction: "))

if d == 1:
    direction = "left"
elif d == 2:
    direction = "right"
else:
    print("Invalid direction")
    exit()

if choice == 1:
    cscan(queue, head, start, end, direction)

elif choice == 2:
    look(queue, head, direction)

elif choice == 3:
    clook(queue, head, direction)

else:
    print("Invalid choice")
# Out:
# Enter start cylinder:  0
# Enter end cylinder:  199
# Enter queue size:  10
# Queue: [100, 73, 43, 181, 15, 91, 3, 149, 138, 79]
# Head: 116
#
# ----- MENU -----
# 1. C-SCAN
# 2. LOOK
# 3. C-LOOK
# Enter choice:  1
# Direction:
# 1. Left
# 2. Right
# Enter direction:  1
# C-SCAN
# Service Order: [116, 100, 91, 79, 73, 43, 15, 3, 0, 199, 181, 149, 138]
# Total Head Movement: 376

# %%
import random
import matplotlib.pyplot as plt


# -------- GRAPH FUNCTION --------
def plot_graph(order, title):
    plt.figure(figsize=(12, 6))   # 2:1 ratio

    y = [i/2 for i in range(len(order))]   # scaled Y-axis
    plt.plot(order, y, marker='o')
    plt.gca().invert_yaxis()

    plt.xlabel("Cylinder Number")
    plt.ylabel("Step Number")
    plt.title(title)

    plt.show()


# -------- C-SCAN (Jump INCLUDED) --------
def cscan(queue, head, start, end, direction):

    left = sorted([x for x in queue if x < head])
    right = sorted([x for x in queue if x >= head])

    order = [head]

    if direction == "right":
        order += right
        order.append(end)
        order.append(start)
        order += left

    else:  # left
        order += left[::-1]
        order.append(start)
        order.append(end)
        order += right[::-1]

    # INCLUDE jump → no skipping
    total = 0
    for i in range(len(order)-1):
        total += abs(order[i+1] - order[i])

    print("\nC-SCAN ")
    print("Service Order:", order)
    print("Total Head Movement:", total)

    plot_graph(order, "C-SCAN Disk Scheduling")


# -------- LOOK --------
def look(queue, head, direction):

    left = sorted([x for x in queue if x < head])
    right = sorted([x for x in queue if x >= head])

    order = [head]

    if direction == "right":
        order += right
        order += left[::-1]

    else:
        order += left[::-1]
        order += right

    total = 0
    for i in range(len(order)-1):
        total += abs(order[i+1] - order[i])

    print("\nLOOK")
    print("Service Order:", order)
    print("Total Head Movement:", total)

    plot_graph(order, "LOOK Disk Scheduling")


# -------- C-LOOK (Jump INCLUDED) --------
def clook(queue, head, direction):

    left = sorted([x for x in queue if x < head])
    right = sorted([x for x in queue if x >= head])

    order = [head]

    if direction == "right":
        order += right
        order += left   # circular jump happens here

    else:
        order += left[::-1]
        order += right[::-1]  # circular jump happens here

    # INCLUDE jump
    total = 0
    for i in range(len(order)-1):
        total += abs(order[i+1] - order[i])

    print("\nC-LOOK")
    print("Service Order:", order)
    print("Total Head Movement:", total)

    plot_graph(order, "C-LOOK Disk Scheduling")


# -------- MAIN --------
start = int(input("Enter start cylinder: "))
end = int(input("Enter end cylinder: "))
qsize = int(input("Enter queue size: "))

queue = [random.randint(start, end) for _ in range(qsize)]
head = random.randint(start, end)

print("\nQueue:", queue)
print("Head:", head)

print("\n----- MENU -----")
print("1. C-SCAN")
print("2. LOOK")
print("3. C-LOOK")

choice = int(input("Enter choice: "))

print("\nDirection:")
print("1. Left")
print("2. Right")

d = int(input("Enter direction: "))

if d == 1:
    direction = "left"
elif d == 2:
    direction = "right"
else:
    print("Invalid direction")
    exit()

if choice == 1:
    cscan(queue, head, start, end, direction)

elif choice == 2:
    look(queue, head, direction)

elif choice == 3:
    clook(queue, head, direction)

else:
    print("Invalid choice")
# Out:
# Enter start cylinder:  0
# Enter end cylinder:  199
# Enter queue size:  10
# Queue: [53, 42, 107, 110, 74, 27, 25, 32, 64, 97]
# Head: 116
#
# ----- MENU -----
# 1. C-SCAN
# 2. LOOK
# 3. C-LOOK
# Enter choice:  1
# Direction:
# 1. Left
# 2. Right
# Enter direction:  2
# C-SCAN
# Service Order: [116, 199, 0, 25, 27, 32, 42, 53, 64, 74, 97, 107, 110]
# Total Head Movement: 392

# %%
import random
import matplotlib.pyplot as plt


# -------- GRAPH FUNCTION --------
def plot_graph(order, title):
    plt.figure(figsize=(12, 6))   # 2:1 ratio

    y = [i/2 for i in range(len(order))]   # scaled Y-axis
    plt.plot(order, y, marker='o')
    plt.gca().invert_yaxis()

    plt.xlabel("Cylinder Number")
    plt.ylabel("Step Number")
    plt.title(title)

    plt.show()


# -------- C-SCAN (Jump INCLUDED) --------
def cscan(queue, head, start, end, direction):

    left = sorted([x for x in queue if x < head])
    right = sorted([x for x in queue if x >= head])

    order = [head]

    if direction == "right":
        order += right
        order.append(end)
        order.append(start)
        order += left

    else:  # left
        order += left[::-1]
        order.append(start)
        order.append(end)
        order += right[::-1]

    # INCLUDE jump → no skipping
    total = 0
    for i in range(len(order)-1):
        total += abs(order[i+1] - order[i])

    print("\nC-SCAN ")
    print("Service Order:", order)
    print("Total Head Movement:", total)

    plot_graph(order, "C-SCAN Disk Scheduling")


# -------- LOOK --------
def look(queue, head, direction):

    left = sorted([x for x in queue if x < head])
    right = sorted([x for x in queue if x >= head])

    order = [head]

    if direction == "right":
        order += right
        order += left[::-1]

    else:
        order += left[::-1]
        order += right

    total = 0
    for i in range(len(order)-1):
        total += abs(order[i+1] - order[i])

    print("\nLOOK")
    print("Service Order:", order)
    print("Total Head Movement:", total)

    plot_graph(order, "LOOK Disk Scheduling")


# -------- C-LOOK (Jump INCLUDED) --------
def clook(queue, head, direction):

    left = sorted([x for x in queue if x < head])
    right = sorted([x for x in queue if x >= head])

    order = [head]

    if direction == "right":
        order += right
        order += left   # circular jump happens here

    else:
        order += left[::-1]
        order += right[::-1]  # circular jump happens here

    # INCLUDE jump
    total = 0
    for i in range(len(order)-1):
        total += abs(order[i+1] - order[i])

    print("\nC-LOOK")
    print("Service Order:", order)
    print("Total Head Movement:", total)

    plot_graph(order, "C-LOOK Disk Scheduling")


# -------- MAIN --------
start = int(input("Enter start cylinder: "))
end = int(input("Enter end cylinder: "))
qsize = int(input("Enter queue size: "))

queue = [random.randint(start, end) for _ in range(qsize)]
head = random.randint(start, end)

print("\nQueue:", queue)
print("Head:", head)

print("\n----- MENU -----")
print("1. C-SCAN")
print("2. LOOK")
print("3. C-LOOK")

choice = int(input("Enter choice: "))

print("\nDirection:")
print("1. Left")
print("2. Right")

d = int(input("Enter direction: "))

if d == 1:
    direction = "left"
elif d == 2:
    direction = "right"
else:
    print("Invalid direction")
    exit()

if choice == 1:
    cscan(queue, head, start, end, direction)

elif choice == 2:
    look(queue, head, direction)  

    

elif choice == 3:
    clook(queue, head, direction)

else:
    print("Invalid choice")
# Out:
# Enter start cylinder:  0
# Enter end cylinder:  199
# Enter queue size:  10
# Queue: [127, 191, 35, 142, 169, 178, 175, 90, 139, 105]
# Head: 95
#
# ----- MENU -----
# 1. C-SCAN
# 2. LOOK
# 3. C-LOOK
# Enter choice:  2
# Direction:
# 1. Left
# 2. Right
# Enter direction:  1
# LOOK
# Service Order: [95, 90, 35, 105, 127, 139, 142, 169, 175, 178, 191]
# Total Head Movement: 216

# %%
import random
import matplotlib.pyplot as plt


# -------- GRAPH FUNCTION --------
def plot_graph(order, title):
    plt.figure(figsize=(12, 6))   # 2:1 ratio

    y = [i/2 for i in range(len(order))]   # scaled Y-axis
    plt.plot(order, y, marker='o')
    plt.gca().invert_yaxis()

    plt.xlabel("Cylinder Number")
    plt.ylabel("Step Number")
    plt.title(title)

    plt.show()


# -------- C-SCAN (Jump INCLUDED) --------
def cscan(queue, head, start, end, direction):

    left = sorted([x for x in queue if x < head])
    right = sorted([x for x in queue if x >= head])

    order = [head]

    if direction == "right":
        order += right
        order.append(end)
        order.append(start)
        order += left

    else:  # left
        order += left[::-1]
        order.append(start)
        order.append(end)
        order += right[::-1]

    # INCLUDE jump → no skipping
    total = 0
    for i in range(len(order)-1):
        total += abs(order[i+1] - order[i])

    print("\nC-SCAN ")
    print("Service Order:", order)
    print("Total Head Movement:", total)

    plot_graph(order, "C-SCAN Disk Scheduling")


# -------- LOOK --------
def look(queue, head, direction):

    left = sorted([x for x in queue if x < head])
    right = sorted([x for x in queue if x >= head])

    order = [head]

    if direction == "right":
        order += right
        order += left[::-1]

    else:
        order += left[::-1]
        order += right

    total = 0
    for i in range(len(order)-1):
        total += abs(order[i+1] - order[i])

    print("\nLOOK")
    print("Service Order:", order)
    print("Total Head Movement:", total)

    plot_graph(order, "LOOK Disk Scheduling")


# -------- C-LOOK (Jump INCLUDED) --------
def clook(queue, head, direction):

    left = sorted([x for x in queue if x < head])
    right = sorted([x for x in queue if x >= head])

    order = [head]

    if direction == "right":
        order += right
        order += left   # circular jump happens here

    else:
        order += left[::-1]
        order += right[::-1]  # circular jump happens here

    # INCLUDE jump
    total = 0
    for i in range(len(order)-1):
        total += abs(order[i+1] - order[i])

    print("\nC-LOOK")
    print("Service Order:", order)
    print("Total Head Movement:", total)

    plot_graph(order, "C-LOOK Disk Scheduling")


# -------- MAIN --------
start = int(input("Enter start cylinder: "))
end = int(input("Enter end cylinder: "))
qsize = int(input("Enter queue size: "))

queue = [random.randint(start, end) for _ in range(qsize)]
head = random.randint(start, end)

print("\nQueue:", queue)
print("Head:", head)

print("\n----- MENU -----")
print("1. C-SCAN")
print("2. LOOK")
print("3. C-LOOK")

choice = int(input("Enter choice: "))

print("\nDirection:")
print("1. Left")
print("2. Right")

d = int(input("Enter direction: "))

if d == 1:
    direction = "left"
elif d == 2:
    direction = "right"
else:
    print("Invalid direction")
    exit()

if choice == 1:
    cscan(queue, head, start, end, direction)

elif choice == 2:
    look(queue, head, direction)

elif choice == 3:
    clook(queue, head, direction)

else:
    print("Invalid choice")
# Out:
# Enter start cylinder:  0
# Enter end cylinder:  199
# Enter queue size:  10
# Queue: [171, 24, 114, 110, 70, 196, 83, 141, 11, 184]
# Head: 125
#
# ----- MENU -----
# 1. C-SCAN
# 2. LOOK
# 3. C-LOOK
# Enter choice:  2
# Direction:
# 1. Left
# 2. Right
# Enter direction:  2
# LOOK
# Service Order: [125, 141, 171, 184, 196, 114, 110, 83, 70, 24, 11]
# Total Head Movement: 256

# %%
import random
import matplotlib.pyplot as plt


# -------- GRAPH FUNCTION --------
def plot_graph(order, title):
    plt.figure(figsize=(12, 6))   # 2:1 ratio

    y = [i/2 for i in range(len(order))]   # scaled Y-axis
    plt.plot(order, y, marker='o')
    plt.gca().invert_yaxis()

    plt.xlabel("Cylinder Number")
    plt.ylabel("Step Number")
    plt.title(title)

    plt.show()


# -------- C-SCAN (Jump INCLUDED) --------
def cscan(queue, head, start, end, direction):

    left = sorted([x for x in queue if x < head])
    right = sorted([x for x in queue if x >= head])

    order = [head]

    if direction == "right":
        order += right
        order.append(end)
        order.append(start)
        order += left

    else:  # left
        order += left[::-1]
        order.append(start)
        order.append(end)
        order += right[::-1]

    # INCLUDE jump → no skipping
    total = 0
    for i in range(len(order)-1):
        total += abs(order[i+1] - order[i])

    print("\nC-SCAN ")
    print("Service Order:", order)
    print("Total Head Movement:", total)

    plot_graph(order, "C-SCAN Disk Scheduling")


# -------- LOOK --------
def look(queue, head, direction):

    left = sorted([x for x in queue if x < head])
    right = sorted([x for x in queue if x >= head])

    order = [head]

    if direction == "right":
        order += right
        order += left[::-1]

    else:
        order += left[::-1]
        order += right

    total = 0
    for i in range(len(order)-1):
        total += abs(order[i+1] - order[i])

    print("\nLOOK")
    print("Service Order:", order)
    print("Total Head Movement:", total)

    plot_graph(order, "LOOK Disk Scheduling")


# -------- C-LOOK (Jump INCLUDED) --------
def clook(queue, head, direction):

    left = sorted([x for x in queue if x < head])
    right = sorted([x for x in queue if x >= head])

    order = [head]

    if direction == "right":
        order += right
        order += left   # circular jump happens here

    else:
        order += left[::-1]
        order += right[::-1]  # circular jump happens here

    # INCLUDE jump
    total = 0
    for i in range(len(order)-1):
        total += abs(order[i+1] - order[i])

    print("\nC-LOOK")
    print("Service Order:", order)
    print("Total Head Movement:", total)

    plot_graph(order, "C-LOOK Disk Scheduling")


# -------- MAIN --------
start = int(input("Enter start cylinder: "))
end = int(input("Enter end cylinder: "))
qsize = int(input("Enter queue size: "))

queue = [random.randint(start, end) for _ in range(qsize)]
head = random.randint(start, end)

print("\nQueue:", queue)
print("Head:", head)

print("\n----- MENU -----")
print("1. C-SCAN")
print("2. LOOK")
print("3. C-LOOK")

choice = int(input("Enter choice: "))

print("\nDirection:")
print("1. Left")
print("2. Right")

d = int(input("Enter direction: "))

if d == 1:
    direction = "left"
elif d == 2:
    direction = "right"
else:
    print("Invalid direction")
    exit()

if choice == 1:
    cscan(queue, head, start, end, direction)

elif choice == 2:
    look(queue, head, direction)

elif choice == 3:
    clook(queue, head, direction)

else:
    print("Invalid choice")
# Out:
# Enter start cylinder:  0
# Enter end cylinder:  199
# Enter queue size:  10
# Queue: [4, 40, 29, 3, 144, 131, 127, 84, 29, 18]
# Head: 54
#
# ----- MENU -----
# 1. C-SCAN
# 2. LOOK
# 3. C-LOOK
# Enter choice:  3
# Direction:
# 1. Left
# 2. Right
# Enter direction:  1
# C-LOOK
# Service Order: [54, 40, 29, 29, 18, 4, 3, 144, 131, 127, 84]
# Total Head Movement: 252

# %%
import random
import matplotlib.pyplot as plt


# -------- GRAPH FUNCTION --------
def plot_graph(order, title):
    plt.figure(figsize=(12, 6))   # 2:1 ratio

    y = [i/2 for i in range(len(order))]   # scaled Y-axis
    plt.plot(order, y, marker='o')
    plt.gca().invert_yaxis()

    plt.xlabel("Cylinder Number")
    plt.ylabel("Step Number")
    plt.title(title)

    plt.show()


# -------- C-SCAN (Jump INCLUDED) --------
def cscan(queue, head, start, end, direction):

    left = sorted([x for x in queue if x < head])
    right = sorted([x for x in queue if x >= head])

    order = [head]

    if direction == "right":
        order += right
        order.append(end)
        order.append(start)
        order += left

    else:  # left
        order += left[::-1]
        order.append(start)
        order.append(end)
        order += right[::-1]

    # INCLUDE jump → no skipping
    total = 0
    for i in range(len(order)-1):
        total += abs(order[i+1] - order[i])

    print("\nC-SCAN ")
    print("Service Order:", order)
    print("Total Head Movement:", total)

    plot_graph(order, "C-SCAN Disk Scheduling")


# -------- LOOK --------
def look(queue, head, direction):

    left = sorted([x for x in queue if x < head])
    right = sorted([x for x in queue if x >= head])

    order = [head]

    if direction == "right":
        order += right
        order += left[::-1]

    else:
        order += left[::-1]
        order += right

    total = 0
    for i in range(len(order)-1):
        total += abs(order[i+1] - order[i])

    print("\nLOOK")
    print("Service Order:", order)
    print("Total Head Movement:", total)

    plot_graph(order, "LOOK Disk Scheduling")


# -------- C-LOOK (Jump INCLUDED) --------
def clook(queue, head, direction):

    left = sorted([x for x in queue if x < head])
    right = sorted([x for x in queue if x >= head])

    order = [head]

    if direction == "right":
        order += right
        order += left   # circular jump happens here

    else:
        order += left[::-1]
        order += right[::-1]  # circular jump happens here

    # INCLUDE jump
    total = 0
    for i in range(len(order)-1):
        total += abs(order[i+1] - order[i])

    print("\nC-LOOK")
    print("Service Order:", order)
    print("Total Head Movement:", total)

    plot_graph(order, "C-LOOK Disk Scheduling")


# -------- MAIN --------
start = int(input("Enter start cylinder: "))
end = int(input("Enter end cylinder: "))
qsize = int(input("Enter queue size: "))

queue = [random.randint(start, end) for _ in range(qsize)]
head = random.randint(start, end)

print("\nQueue:", queue)
print("Head:", head)

print("\n----- MENU -----")
print("1. C-SCAN")
print("2. LOOK")
print("3. C-LOOK")

choice = int(input("Enter choice: "))

print("\nDirection:")
print("1. Left")
print("2. Right")

d = int(input("Enter direction: "))

if d == 1:
    direction = "left"
elif d == 2:
    direction = "right"
else:
    print("Invalid direction")
    exit()

if choice == 1:
    cscan(queue, head, start, end, direction)

elif choice == 2:
    look(queue, head, direction)

elif choice == 3:
    clook(queue, head, direction)

else:
    print("Invalid choice")
# Out:
# Enter start cylinder:  0
# Enter end cylinder:  199
# Enter queue size:  10
# Queue: [189, 160, 33, 92, 182, 85, 156, 181, 39, 94]
# Head: 129
#
# ----- MENU -----
# 1. C-SCAN
# 2. LOOK
# 3. C-LOOK
# Enter choice:  3
# Direction:
# 1. Left
# 2. Right
# Enter direction:  2
# C-LOOK
# Service Order: [129, 156, 160, 181, 182, 189, 33, 39, 85, 92, 94]
# Total Head Movement: 277
