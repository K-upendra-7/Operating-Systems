# %%
import random
import matplotlib.pyplot as plt
import pandas as pd

# Input
num_processes = int(input("Enter number of processes: "))
processes = []

for i in range(num_processes):
    processes.append({
        'PID': f'P{i+1}',
        'AT': random.randint(0, 10),
        'BT': random.randint(1, 10)
    })

# Calculation 
processes.sort(key=lambda x: x['AT'])

current_time = 0
total_tat = 0
total_wt = 0
timeline = [] 

for p in processes:

    if current_time < p['AT']:
        timeline.append(('Idle', current_time, p['AT']))
        current_time = p['AT']
    
    p['Start'] = current_time
    p['CT'] = current_time + p['BT']
    p['TAT'] = p['CT'] - p['AT']
    p['WT'] = p['TAT'] - p['BT']
    
    total_tat += p['TAT']
    total_wt += p['WT']
    timeline.append((p['PID'], p['Start'], p['CT']))
    
    current_time = p['CT']

avg_tat = total_tat / len(processes)
avg_wt = total_wt / len(processes)

# Output
df = pd.DataFrame(processes).sort_values(by='PID')
print("FCFS Scheduler")
print(df.to_string(index=False))
print(f"Average Waiting Time:    {avg_wt:.2f}")
print(f"Average Turnaround Time: {avg_tat:.2f}")

# Plot
fig, ax = plt.subplots(figsize=(10, 5))

# Get unique PIDs for Y-axis
unique_pids = df['PID'].unique()
y_positions = {pid: i for i, pid in enumerate(unique_pids)}

# Calculate the middle Y point for placing the 'Idle' label clearly
mid_y = len(unique_pids) / 2 - 0.5

for label, start, end in timeline:
    duration = end - start

    if duration == 0: continue
        
    if label == 'Idle':
        # Draw Red Bar for Idle (Full height)
        ax.broken_barh([(start, duration)], (-0.5, len(unique_pids)), facecolors='tab:red', alpha=0.5)

        # Add "Idle" Label in the center of the block
        ax.text(start + duration/2, mid_y, "Idle", ha='center', va='center', color='white', fontweight='bold', rotation=90)
    else:
        # Draw Blue Bar for Process
        y = y_positions[label]
        ax.broken_barh([(start, duration)], (y - 0.4, 0.8), facecolors='tab:blue', edgecolor='black')
        
        # Add PID Label in the center of the bar
        ax.text(start + duration/2, y, label, ha='center', va='center', color='white', fontweight='bold')

# Formatting
ax.set_yticks(range(len(unique_pids)))
ax.set_yticklabels(unique_pids)
ax.set_xlabel('Time')
ax.set_ylabel('Process ID')
ax.set_title('Gantt Chart - FCFS')
ax.grid(True, axis='x', linestyle = '--', alpha=0.6)

plt.tight_layout()
plt.show()
# Out:
# FCFS Scheduler
# PID  AT  BT  Start  CT  TAT  WT
#  P1   9   7     28  35   26  19
#  P2   4   2      4   6    2   0
#  P3   8  10     18  28   20  10
#  P4   4   2      6   8    4   2
#  P5   5  10      8  18   13   3
# Average Waiting Time:    6.80
# Average Turnaround Time: 13.00

# %%
import random
import matplotlib.pyplot as plt
import pandas as pd

# Input
num_processes = int(input("Enter number of processes: "))
processes = []

for i in range(num_processes):
    processes.append({
        'PID': f'P{i+1}',
        'AT': random.randint(0, 10),
        'BT': random.randint(1, 10)
    })

# Calculation 
processes.sort(key=lambda x: x['AT'])

current_time = 0
total_tat = 0
total_wt = 0
timeline = [] 

for p in processes:

    if current_time < p['AT']:
        timeline.append(('Idle', current_time, p['AT']))
        current_time = p['AT']
    
    p['Start'] = current_time
    p['CT'] = current_time + p['BT']
    p['TAT'] = p['CT'] - p['AT']
    p['WT'] = p['TAT'] - p['BT']
    
    total_tat += p['TAT']
    total_wt += p['WT']
    timeline.append((p['PID'], p['Start'], p['CT']))
    
    current_time = p['CT']

avg_tat = total_tat / len(processes)
avg_wt = total_wt / len(processes)

# Output
df = pd.DataFrame(processes).sort_values(by='PID')
print("FCFS Scheduler")
print(df.to_string(index=False))
print(f"Average Waiting Time:    {avg_wt:.2f}")
print(f"Average Turnaround Time: {avg_tat:.2f}")

# Plot
fig, ax = plt.subplots(figsize=(10, 5))

# Get unique PIDs for Y-axis
unique_pids = df['PID'].unique()
y_positions = {pid: i for i, pid in enumerate(unique_pids)}

# Calculate the middle Y point for placing the 'Idle' label clearly
mid_y = len(unique_pids) / 2 - 0.5

for label, start, end in timeline:
    duration = end - start

    if duration == 0: continue
        
    if label == 'Idle':
        # Draw Red Bar for Idle (Full height)
        ax.broken_barh([(start, duration)], (-0.5, len(unique_pids)), facecolors='tab:red', alpha=0.5)

        # Add "Idle" Label in the center of the block
        ax.text(start + duration/2, mid_y, "Idle", ha='center', va='center', color='white', fontweight='bold', rotation=90)
    else:
        # Draw Blue Bar for Process
        y = y_positions[label]
        ax.broken_barh([(start, duration)], (y - 0.4, 0.8), facecolors='tab:blue', edgecolor='black')
        
        # Add PID Label in the center of the bar
        ax.text(start + duration/2, y, label, ha='center', va='center', color='white', fontweight='bold')

# Formatting
ax.set_yticks(range(len(unique_pids)))
ax.set_yticklabels(unique_pids)
ax.set_xlabel('Time')
ax.set_ylabel('Process ID')
ax.set_title('Gantt Chart - FCFS')
ax.grid(True, axis='x', linestyle = '--', alpha=0.6)

plt.tight_layout()
plt.show()
# Out:
# FCFS Scheduler
# PID  AT  BT  Start  CT  TAT  WT
#  P1   6   5     22  27   21  16
#  P2   6   4     27  31   25  21
#  P3   1  10      4  14   13   3
#  P4   9   6     31  37   28  22
#  P5   0   4      0   4    4   0
#  P6   5   8     14  22   17   9
# Average Waiting Time:    11.83
# Average Turnaround Time: 18.00

# %%
# Out:
# [{'PID': 'P1', 'AT': 4, 'BT': 5}, {'PID': 'P2', 'AT': 5, 'BT': 9}, {'PID': 'P3', 'AT': 6, 'BT': 5}, {'PID': 'P4', 'AT': 5, 'BT': 6}, {'PID': 'P5', 'AT': 6, 'BT': 4}]
